# %% [raw]
# 1. What does an empty dictionary's code look like?
#
# Ans: An empty dictionary can be represented using two empty curly brackets
#
#      d = {} or d = dict()

# %% [raw]
# 2. What is the value of a dictionary value with the key 'foo' and the value 42?
#
# Ans: {'foo':42}

# %% [raw]
# 3. What is the most significant distinction between a dictionary and a list?
#
# Ans: The most significant distinction between a dictionary and a list are:
#
#     1. The Items stored in a dictionary are unordered whereas the items in a list are ordered.
#     2. Dictionaries are represented using curly braces, {}, where as lists are represented using square
#        brackets, [].

# %% [raw]
# 4. What happens if you try to access spam['foo'] if spam is {'bar': 100}?
#
# Ans: We will get a keyError.
#
# Example Code:

# %%
spam = {'bar': 100}

print(spam['foo'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [1], in <cell line: 3>()
#       1 spam = {'bar': 100}
# ----> 3 print(spam['foo'])
#
# KeyError: 'foo'

# %% [raw]
# 5. If a dictionary is stored in spam, what is the difference between the expressions 'cat' in spam and
# 'cat' in spam.keys()?
#
# Ans: There is no difference, in both these cases the operator checks whether a value exits as a key in the dictionary or not.

# %% [raw]
# 6. If a dictionary is stored in spam, what is the difference between the expressions'cat' in spam and
# 'cat' in spam.values()?
#
# Ans: 'cat' in spam checks whether there is a 'cat' key in the dictionary, while 'cat' in spam.values() checks whether there is a value 'cat' for one of the keys in spam.

# %% [raw]
# 7. What is a shortcut for the following code?
#
#     if 'color' not in spam:
#         spam['color'] = 'black'
#
# Ans: spam.setdefault('color','black')

# %% [raw]
# 8. How do you 'pretty print' dictionary values using which module and function?
#
# Ans: We can 'pretty print' dictionary values by using:
#
#     1. pprint() function of pprint module (pprint() is not applicable for nested dictionaries)
#     2. dumps() method of json module
#     3. dump() method of yaml module
#
# Example Code:

# %%
import pprint
import json
import yaml

dict1 = [
  {'Name': 'John', 'Age': '23', 'Country': 'USA'},
  {'Name': 'Jose', 'Age': '44', 'Country': 'Spain'},
  {'Name': 'Anne', 'Age': '29', 'Country': 'UK'},
  {'Name': 'Lee', 'Age': '35', 'Country': 'Japan'}
]



#nested dictionary:

dict2 = [
  {'Name': 'John', 'Age': '23', 'Residence': {'Country':'USA', 'City': 'New York'}},
  {'Name': 'Jose', 'Age': '44', 'Residence': {'Country':'Spain', 'City': 'Madrid'}},
  {'Name': 'Anne', 'Age': '29', 'Residence': {'Country':'UK', 'City': 'England'}},
  {'Name': 'Lee', 'Age': '35', 'Residence': {'Country':'Japan', 'City': 'Osaka'}}
]


d1 = json.dumps(dict1, indent=4)
d11 = json.dumps(dict2, indent=4)

d2 = yaml.dump(dict1)
d22 = yaml.dump(dict2)

print('Printing using print() function: \n\ndict1:\n\n',dict1,'\n\ndict2:\n\n',dict2,'\n')
print('*'*50)
print('\nPrinting using pprint() function: \n\ndict1:\n',)

pprint.pprint(d)

print('\ndict2:\n')

pprint.pprint(d1)

print('\n')
print('*'*50)
print('\nPrinting using dumps() method in json: \n\ndict1:\n\n',d1,'\n\ndict2:\n\n',d11,'\n')

print('*'*50)
print('\nPrinting using dump() method in yaml: \n\ndict1:\n\n',d2,'\n\ndict2:\n\n',d22)
# Out:
# Printing using print() function:
#
# dict1:
#
#  [{'Name': 'John', 'Age': '23', 'Country': 'USA'}, {'Name': 'Jose', 'Age': '44', 'Country': 'Spain'}, {'Name': 'Anne', 'Age': '29', 'Country': 'UK'}, {'Name': 'Lee', 'Age': '35', 'Country': 'Japan'}]
#
# dict2:
#
#  [{'Name': 'John', 'Age': '23', 'Residence': {'Country': 'USA', 'City': 'New York'}}, {'Name': 'Jose', 'Age': '44', 'Residence': {'Country': 'Spain', 'City': 'Madrid'}}, {'Name': 'Anne', 'Age': '29', 'Residence': {'Country': 'UK', 'City': 'England'}}, {'Name': 'Lee', 'Age': '35', 'Residence': {'Country': 'Japan', 'City': 'Osaka'}}]
#
# **************************************************
#
# Printing using pprint() function:
#
# dict1:
#
# [{'Age': '23', 'Country': 'USA', 'Name': 'John'},
#  {'Age': '44', 'Country': 'Spain', 'Name': 'Jose'},
#  {'Age': '29', 'Country': 'UK', 'Name': 'Anne'},
#  {'Age': '35', 'Country': 'Japan', 'Name': 'Lee'}]
#
# dict2:
#
# ('[\n'
#  '    {\n'
#  '        "Name": "John",\n'
# ...
